# %%
from PIL import  Image

# %%
file='/home/augusto/camaleon.jpg'

# %%
img=Image.open(file)

# %%
img.show()

# %%
img.save('camaleon.jpg')

# %%
file2='/home/augusto/olas.jpg'
img2=Image.open(file2)

# %%
img2.show()

# %%
r,g,b=img.split()

# %%
img3=Image.merge('RGB',(b,g,r))

# %%
img3.show()

# %%
img.show()

# %%
r,g,b=img2.split()
img4=Image.merge('RGB',(g,r,b))
img2.show()
img4.show()

# %%
img2.show()
img4.show()

# %%
img5=img.resize((300,200))

# %%
img2.paste(img5,(0,0))

# %%
img2.show()

# %%
img6=img3.resize((300,200))
img2.paste(img6,(250,250))

# %%
img2.save('pegote_camaleones.jpg')

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=774x516 at 0x7F2470914220>
