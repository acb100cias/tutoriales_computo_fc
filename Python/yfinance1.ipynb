# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# WARNING: Error parsing dependencies of gpg: Invalid version: '1.14.0-unknown'
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import yfinance as yf

# %%
gog=yf.Ticker('goog')

# %%
dir(gog)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fundamentals',
#  '_get_ticker_tz',
#  '_holders',
#  '_isin',
#  '_lazy_load_price_history',
#  '_news',
#  '_options2df',
#  '_price_history',
#  '_quote',
#  '_shares',
#  '_tz',
#  '_underlying',
#  'actions',
#  'analyst_price_target',
#  'balance_sheet',
#  'balancesheet',
#  'basic_info',
#  'calendar',
#  'capital_gains',
#  'cash_flow',
#  'cashflow',
#  'dividends',
#  'earnings',
# ...

# %%
DatosGoog=gog.history()

# %%
len(DatosGoog)
# Out:
# 23

# %%
DatosGoog2=gog.history(start='2023-01-03',end='2023-01-10')

# %%
len(DatosGoog2)
# Out:
# 5

# %%
DatosGoog
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-07-01 00:00:00-04:00  184.479996  185.339996  182.729996  184.490005
# 2024-07-02 00:00:00-04:00  183.470001  186.949997  183.059998  186.610001
# 2024-07-03 00:00:00-04:00  186.300003  187.619995  185.384995  187.389999
# 2024-07-05 00:00:00-04:00  187.320007  192.259995  187.320007  191.960007
# 2024-07-08 00:00:00-04:00  191.365005  191.679001  189.320007  190.479996
# 2024-07-09 00:00:00-04:00  191.750000  192.860001  190.229996  190.440002
# 2024-07-10 00:00:00-04:00  190.750000  193.309998  190.619995  192.660004
# 2024-07-11 00:00:00-04:00  191.339996  192.410004  186.820007  187.300003
# 2024-07-12 00:00:00-04:00  186.919998  188.690002  186.139999  186.779999
# 2024-07-15 00:00:00-04:00  186.490005  189.899994  186.490005  188.190002
# 2024-07-16 00:00:00-04:00  188.960007  190.339996  185.119995  185.500000
# 2024-07-17 00:00:00-04:00  184.679993  185.229996  181.619995  182.619995
# ...

# %%
data2=yf.download(['GOOG','META'],period='1mo')
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
data2.tail()
# Out:
# Price        Adj Close                   Close                    High  \
# Ticker            GOOG        META        GOOG        META        GOOG
# Date
# 2024-07-26  168.679993  465.700012  168.679993  465.700012  169.839996
# 2024-07-29  171.130005  465.709991  171.130005  465.709991  172.160004
# 2024-07-30  171.860001  463.190002  171.860001  463.190002  172.949997
# 2024-07-31  173.149994  474.829987  173.149994  474.829987  175.910004
# 2024-08-01  171.830002  501.060913  171.830002  501.060913  175.679993
#
# Price                          Low                    Open              \
# Ticker            META        GOOG        META        GOOG        META
# Date
# 2024-07-26  469.769989  165.865005  459.420013  168.770004  464.200012
# 2024-07-29  473.959991  169.720001  465.019989  170.500000  469.880005
# 2024-07-30  472.730011  170.119995  456.700012  171.830002  467.000000
# 2024-07-31  476.500000  171.720001  466.750000  174.919998  471.019989
# ...

# %%
data3=yf.download(['GOOG','META','AAPL'],period='1mo',group_by='ticker')
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
data3.head()
# Out:
# Ticker            META                                                  \
# Price             Open        High         Low       Close   Adj Close
# Date
# 2024-07-01  504.950012  506.579987  493.170013  504.679993  504.679993
# 2024-07-02  500.760010  510.500000  499.450012  509.500000  509.500000
# 2024-07-03  506.369995  511.279999  506.019989  509.959991  509.959991
# 2024-07-05  511.600006  540.869995  511.600006  539.909973  539.909973
# 2024-07-08  542.349976  542.809998  526.650024  529.320007  529.320007
#
# Ticker                      GOOG                                      \
# Price         Volume        Open        High         Low       Close
# Date
# 2024-07-01  10328200  184.479996  185.339996  182.729996  184.490005
# 2024-07-02   7739500  183.470001  186.949997  183.059998  186.610001
# 2024-07-03   6005600  186.300003  187.619995  185.384995  187.389999
# 2024-07-05  21354100  187.320007  192.259995  187.320007  191.960007
# ...

# %%
pd.DataFrame(gog.info).keys().values
# Out:
# array(['address1', 'city', 'state', 'zip', 'country', 'phone', 'website',
#        'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey',
#        'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees',
#        'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk',
#        'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate',
#        'compensationAsOfEpochDate', 'maxAge', 'priceHint',
#        'previousClose', 'open', 'dayLow', 'dayHigh',
#        'regularMarketPreviousClose', 'regularMarketOpen',
#        'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate',
#        'dividendYield', 'exDividendDate', 'payoutRatio', 'beta',
#        'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume',
#        'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day',
#        'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow',
#        'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months',
# ...

# %%
meta=yf.Ticker('META')

# %%
pd.DataFrame(meta.info)
# Out:
#      address1        city state    zip        country         phone  \
# 0  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 1  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 2  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 3  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 4  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 5  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 6  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 7  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 8  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
# 9  1 Meta Way  Menlo Park    CA  94025  United States  650 543 4800
#
#                    website                        industry  \
# 0  https://investor.fb.com  Internet Content & Information
# 1  https://investor.fb.com  Internet Content & Information
# ...

# %%
pd.DataFrame(yf.Ticker('AAPL').info)
# Out:
#              address1       city state    zip        country         phone  \
# 0  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 1  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 2  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 3  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 4  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 5  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 6  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 7  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 8  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
# 9  One Apple Park Way  Cupertino    CA  95014  United States  408 996 1010
#
#                  website              industry           industryKey  \
# 0  https://www.apple.com  Consumer Electronics  consumer-electronics
# ...

# %%
pd.DataFrame(yf.Ticker('SSNLF').info)
# Out:
#          address1                   address2   city      zip      country  \
# 0  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 1  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 2  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 3  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 4  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 5  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 6  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 7  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 8  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
# 9  129 Samsung-Ro  Maetan-3dong Yeongtong-gu  Suwon  443-742  South Korea
#
#             phone             fax                  website  \
# 0  82 2 2255 0114  82 3 1200 7538  https://www.samsung.com
# ...

# %%
pd.DataFrame(yf.Ticker('NVDA').info)
# Out:
#                     address1         city state    zip        country  \
# 0  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 1  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 2  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 3  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 4  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 5  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 6  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 7  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 8  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
# 9  2788 San Tomas Expressway  Santa Clara    CA  95051  United States
#
#           phone                 website        industry     industryKey  \
# 0  408 486 2000  https://www.nvidia.com  Semiconductors  semiconductors
# ...

# %%
pd.DataFrame(yf.Ticker('AMZN').info)
# Out:
#                  address1     city state         zip        country  \
# 0  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 1  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 2  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 3  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 4  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 5  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 6  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 7  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 8  410 Terry Avenue North  Seattle    WA  98109-5210  United States
# 9  410 Terry Avenue North  Seattle    WA  98109-5210  United States
#
#           phone                      website         industry  \
# 0  206 266 1000  https://www.aboutamazon.com  Internet Retail
# 1  206 266 1000  https://www.aboutamazon.com  Internet Retail
# ...

# %%
amazon=yf.Ticker('AMZN')

# %%
amazon.get_financials()
# Out:
#                                                           2023-12-31  \
# TaxEffectOfUnusualItems                             211380035.679101
# TaxRateForCalcs                                             0.189579
# NormalizedEBITDA                                       88287000000.0
# TotalUnusualItems                                       1115000000.0
# TotalUnusualItemsExcludingGoodwill                      1115000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...     30425000000.0
# ReconciledDepreciation                                 48663000000.0
# ReconciledCostOfRevenue                               480980000000.0
# EBITDA                                                 89402000000.0
# EBIT                                                   40739000000.0
# NetInterestIncome                                       -233000000.0
# InterestExpense                                         3182000000.0
# InterestIncome                                          2949000000.0
# ...
