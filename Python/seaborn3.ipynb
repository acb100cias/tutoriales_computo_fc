# %%
from numpy import *
from pandas import *
import seaborn as sns

# %%
pingus=sns.load_dataset("penguins")

# %%
pingus
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(pingus,x="flipper_length_mm",binwidth=2)

# %%
sns.displot(pingus,x="flipper_length_mm",bins=30)

# %%
propinas=sns.load_dataset("tips")

# %%
propinas
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(propinas,x='size')

# %%
sns.displot(propinas,x='size',bins=[1,2,3,4,5,6,7])

# %%
sns.displot(propinas,x='size',discrete=True)

# %%
sns.displot(propinas,x="day")

# %%
sns.displot(propinas,x="day",shrink=0.8)

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species")

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",element="step")

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",multiple="stack")

# %%
sns.displot(pingus,x="flipper_length_mm",hue="sex",multiple="dodge")

# %%
sns.displot(pingus,x="flipper_length_mm",col="sex")

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",stat="density",multiple='stack')

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",stat="density",multiple='stack',common_norm=False)

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",stat="probability",multiple='stack')

# %%
sns.displot(pingus,x="flipper_length_mm",kind='kde')

# %%
sns.displot(pingus,x="flipper_length_mm",kind='kde',bw_adjust=0.25)

# %%
sns.displot(pingus,x="flipper_length_mm",kind='kde',bw_adjust=2)

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",kind='kde',bw_adjust=0.25)

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",kind='kde',bw_adjust=0.25,multiple="stack")

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",kind='kde',bw_adjust=0.25,fill=True)

# %%
sns.displot(pingus,x="flipper_length_mm",hue="species",multiple="stack",kde=True)

# %%
sns.displot(pingus,x='flipper_length_mm',kind='ecdf')

# %%
sns.displot(pingus,x='flipper_length_mm',hue="species",kind='ecdf')

# %%
sns.displot(pingus,x='flipper_length_mm',hue='sex',kind='ecdf')

# %%
sns.displot(pingus,x='bill_length_mm',y='bill_depth_mm')

# %%
sns.displot(pingus,x='bill_length_mm',y='bill_depth_mm',kind="kde")

# %%
sns.displot(pingus,x='bill_length_mm',y='bill_depth_mm',hue='species')

# %%
sns.displot(pingus,x='bill_length_mm',y='bill_depth_mm',hue='species',kind='kde')

# %%
sns.displot(pingus,x='bill_length_mm',y='bill_depth_mm',binwidth=(2,.5),cbar=True)

# %%
sns.jointplot(data=pingus,x='bill_length_mm',y='bill_depth_mm',hue='species',kind='kde')

# %%
sns.pairplot(pingus)

# %%
g=sns.PairGrid(pingus)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot,fill=True)
g.map_diag(sns.histplot,kde=True)
