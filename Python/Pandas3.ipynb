# %%
from pandas import *
from numpy import *

# %%
Data=read_csv('/home/augusto/Descargas/data kaggle/Spotify_Youtube.csv')

# %%
Data.keys()
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
Data=Data.drop('Unnamed: 0',axis=1)

# %%
DataArtist=Data.groupby('Artist')

# %%
DataFrame(DataArtist)[1][950]
# Out:
#               Artist                                        Url_spotify  \
# 14918  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14919  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14920  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14921  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14922  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14923  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14924  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14925  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14926  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
# 14927  Karsten Glück  https://open.spotify.com/artist/5Asmk7uzCjVJN7...
#
#                                       Track  \
# 14918                              La-Le-Lu
# 14919                            Aramsamsam
# ...

# %%
Data.loc[Data['Artist']=='Metallica'].filter(['Loudness','Album','Track']).max()
# Out:
# Loudness                 -2.96
# Album        Screaming Suicide
# Track       Whiskey In The Jar
# dtype: object

# %%
Data.loc[Data['Artist'] =='Nirvana'].filter(['Loudness','Album','Track']).min()
# Out:
# Loudness                                          -13.58
# Album       In Utero - 20th Anniversary - Deluxe Edition
# Track                                       About A Girl
# dtype: object

# %%
data2=DataFrame()

# %%
data2=data2.append(Data.loc[Data['Artist']=='Metallica'])
# Out:
# <ipython-input-52-e671a3065490>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2=data2.append(Data.loc[Data['Artist']=='Metallica'])

# %%
data2=data2.append(Data.loc[Data['Artist']=='Nirvana'])
# Out:
# <ipython-input-53-be94fcaa15cd>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2=data2.append(Data.loc[Data['Artist']=='Nirvana'])

# %%
data2=data2.reset_index()
data2=data2.drop('index',axis=1)

# %%
data2.filter(['Loudness','Likes','Track']).sort_values(by='Likes')
# Out:
#     Loudness       Likes                                 Track
# 5     -9.150        18.0                      One (Remastered)
# 15   -13.580       140.0                                  Dumb
# 19   -10.628      5315.0                               Rape Me
# 9     -3.448    217109.0                     Screaming Suicide
# 6     -6.145    274106.0  For Whom The Bell Tolls (Remastered)
# 2     -9.108    293409.0        Master of Puppets (Remastered)
# 18   -12.197    402656.0                         All Apologies
# 8     -6.005    418124.0             Sad But True (Remastered)
# 3     -3.751    429797.0                    Whiskey In The Jar
# 7     -2.960    473751.0                            Lux Æterna
# 16    -4.538    513043.0                          About A Girl
# 14   -13.044    766088.0                  Something In The Way
# 12   -10.283   1621101.0                      Heart-Shaped Box
# 17    -6.410   1714761.0                               Lithium
# ...

# %%
data2.groupby('Artist')['Likes','Loudness'].describe()
# Out:
# <ipython-input-71-4bf761b1615d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data2.groupby('Artist')['Likes','Loudness'].describe()
#           Likes                                                        \
#           count       mean           std    min        25%        50%
# Artist
# Metallica  10.0  1184439.8  1.640872e+06   18.0  278931.75   423960.5
# Nirvana    10.0  2270154.3  3.550912e+06  140.0  430252.75  1193594.5
#
#                                   Loudness                            \
#                   75%         max    count    mean       std     min
# Artist
# Metallica  1454705.25   5127599.0     10.0 -6.8242  2.705303  -9.793
# Nirvana    2306120.25  11890310.0     10.0 -9.0019  3.466762 -13.580
#
#
#                 25%     50%     75%    max
# Artist
# Metallica  -9.13950 -7.2785 -4.3145 -2.960
# Nirvana   -11.80475 -9.6100 -5.9870 -4.538

# %%
data2.to_csv('musica_Metallica_Nirvana.csv',index=False)

# %%
read_csv('musica_Metallica_Nirvana.csv')
# Out:
#        Artist                                        Url_spotify  \
# 0   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 1   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 2   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 3   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 4   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 5   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 6   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 7   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 8   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 9   Metallica  https://open.spotify.com/artist/2ye2Wgw4gimLv2...
# 10    Nirvana  https://open.spotify.com/artist/6olE6TJLqED3rq...
# 11    Nirvana  https://open.spotify.com/artist/6olE6TJLqED3rq...
# 12    Nirvana  https://open.spotify.com/artist/6olE6TJLqED3rq...
# ...
