# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
ms=yf.Ticker('MSFT')
apl=yf.Ticker('AAPL')

# %%
ms.history(period='max')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-03-13 00:00:00-05:00    0.054693    0.062736    0.054693    0.060055
# 1986-03-14 00:00:00-05:00    0.060055    0.063272    0.060055    0.062199
# 1986-03-17 00:00:00-05:00    0.062199    0.063808    0.062199    0.063272
# 1986-03-18 00:00:00-05:00    0.063272    0.063808    0.061127    0.061663
# 1986-03-19 00:00:00-05:00    0.061663    0.062199    0.060055    0.060591
# ...                               ...         ...         ...         ...
# 2024-07-29 00:00:00-04:00  431.579987  432.149994  424.700012  426.730011
# 2024-07-30 00:00:00-04:00  427.720001  429.049988  417.359985  422.920013
# 2024-07-31 00:00:00-04:00  420.500000  421.779999  412.209991  418.350006
# 2024-08-01 00:00:00-04:00  420.790009  427.459991  413.089996  417.109985
# 2024-08-02 00:00:00-04:00  412.744995  415.000000  404.339996  405.869995
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
ms.history(period='max')['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
apl.history(period='max')['Close'].plot(label='Apple')
ms.history(period='max')['Close'].plot(label='Microsoft')
plt.legend()

# %%
ibm=yf.Ticker('IBM')
dell=yf.Ticker('DELL')
ibm.history(period='max')['Close'].plot(label='IBM')
dell.history(period='max')['Close'].plot(label='Dell')
apl.history(period='max')['Close'].plot(label='Apple')
plt.legend()

# %%
dell.history(period='max')['Close'].plot(label='Dell')
apl.history(period='max')['Close'].plot(label='Apple')
plt.legend()

# %%
amd=yf.Ticker('AMD')
intel=yf.Ticker('INTC')
nvidia=yf.Ticker('NVDA')
amd.history(period='max')['Close'].plot(label='AMD')
intel.history(period='max')['Close'].plot(label='Intel')
nvidia.history(period='max')['Close'].plot(label='Nvidia')
plt.legend()

# %%
google=yf.Ticker('GOOG')

# %%
google.info['totalCash']
# Out:
# 100724998144

# %%
google.balancesheet
# Out:
#                                                       2023-12-31  \
# Treasury Shares Number                                       0.0
# Ordinary Shares Number                             12460000000.0
# Share Issued                                       12460000000.0
# Total Debt                                         28504000000.0
# Tangible Book Value                               254181000000.0
# ...                                                          ...
# Allowance For Doubtful Accounts Receivable          -771000000.0
# Gross Accounts Receivable                          48735000000.0
# Cash Cash Equivalents And Short Term Investments  110916000000.0
# Other Short Term Investments                       86868000000.0
# Cash And Cash Equivalents                          24048000000.0
#
#                                                       2022-12-31  \
# Treasury Shares Number                                       NaN
# ...

# %%
fin=google.financials
bs=google.balancesheet
fe=google.cashflow

# %%
fe
# Out:
#                                                     2023-12-31     2022-12-31  \
# Free Cash Flow                                   69495000000.0  60010000000.0
# Repurchase Of Capital Stock                     -61504000000.0 -59296000000.0
# Repayment Of Debt                               -11550000000.0 -54068000000.0
# Issuance Of Debt                                 10790000000.0  52872000000.0
# Capital Expenditure                             -32251000000.0 -31485000000.0
# Income Tax Paid Supplemental Data                19164000000.0  18892000000.0
# End Cash Position                                24048000000.0  21879000000.0
# Beginning Cash Position                          21879000000.0  20945000000.0
# Effect Of Exchange Rate Changes                   -421000000.0   -506000000.0
# Changes In Cash                                   2590000000.0   1440000000.0
# Financing Cash Flow                             -72093000000.0 -69757000000.0
# ...

# %%
G=pd.concat([fin,bs,fe])

# %%
G
# Out:
#                                             2023-12-31     2022-12-31  \
# Tax Effect Of Unusual Items               -286479000.0   -981507000.0
# Tax Rate For Calcs                               0.139          0.159
# Normalized EBITDA                       100032000000.0  91333000000.0
# Total Unusual Items                      -2061000000.0  -6173000000.0
# Total Unusual Items Excluding Goodwill   -2061000000.0  -6173000000.0
# ...                                                ...            ...
# Amortization Of Intangibles                        NaN    641000000.0
# Depreciation                             11946000000.0  13475000000.0
# Operating Gains Losses                     823000000.0   5519000000.0
# Gain Loss On Investment Securities         823000000.0   5519000000.0
# Net Income From Continuing Operations    73795000000.0  59972000000.0
#
#                                            2021-12-31        2020-12-31  \
# ...

# %%
tickers=['AMZN','NFLX','GOOG']
tik=[yf.Ticker(ticker)for ticker in tickers]

# %%
tik
# Out:
# [yfinance.Ticker object <AMZN>,
#  yfinance.Ticker object <NFLX>,
#  yfinance.Ticker object <GOOG>]

# %%
DF=[]
for t in tik:
    fin=t.financials
    bs=t.balancesheet
    cf=t.cashflow
    T=pd.concat([fin,bs,cf])
    D=T.T
    D=D.reset_index()
    D.columns=['Fecha',*D.columns[1:]]
    D['Ticker']=t.ticker
    DF.append(D)

# %%
DF
# Out:
# [       Fecha Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
#  0 2019-12-31                         NaN                NaN               NaN
#  1 2020-12-31            287626230.457441           0.118413     48647000000.0
#  2 2021-12-31           1839997169.143666            0.12558     59741000000.0
#  3 2022-12-31               -3415860000.0               0.21     54618000000.0
#  4 2023-12-31            211380035.679101           0.189579     88287000000.0
#
#    Total Unusual Items Total Unusual Items Excluding Goodwill  \
#  0                 NaN                                    NaN
#  1        2429000000.0                           2429000000.0
#  2       14652000000.0                          14652000000.0
#  3      -16266000000.0                         -16266000000.0
#  4        1115000000.0                           1115000000.0
#
#    Net Income From Continuing Operation Net Minority Interest  \
# ...

# %%
T2=pd.concat(DF, ignore_index=True)
T2=T2.set_index(['Ticker','Fecha'])

# %%
T2
# Out:
#                   Tax Effect Of Unusual Items Tax Rate For Calcs  \
# Ticker Fecha
# AMZN   2019-12-31                         NaN                NaN
#        2020-12-31            287626230.457441           0.118413
#        2021-12-31           1839997169.143666            0.12558
#        2022-12-31               -3415860000.0               0.21
#        2023-12-31            211380035.679101           0.189579
# NFLX   2023-12-31                         0.0               0.13
#        2022-12-31                         0.0               0.15
#        2021-12-31                         0.0               0.12
#        2020-12-31                         0.0               0.14
#        2019-12-31                         NaN                NaN
# GOOG   2023-12-31                -286479000.0              0.139
#        2022-12-31                -981507000.0              0.159
#        2021-12-31                1948860000.0              0.162
# ...
