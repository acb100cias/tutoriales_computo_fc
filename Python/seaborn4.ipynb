# %%
from pandas import *
from numpy import *
import seaborn as sns

# %%
prop=sns.load_dataset("tips")

# %%
prop
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(data=prop,x='day',y='total_bill',jitter=True)

# %%
sns.catplot(data=prop,x='day',y='total_bill',kind="swarm")

# %%
sns.catplot(data=prop,x='day',y='total_bill',kind="swarm",hue='sex')

# %%
sns.catplot(data=prop.query("size != 3"),x='size',y='total_bill')

# %%
sns.catplot(data=prop,x='smoker',y='tip',order=["No","Yes"])

# %%
sns.catplot(data=prop,x='smoker',y='tip')

# %%
sns.catplot(data=prop,x='total_bill',y='day',hue='time',kind='swarm')

# %%
sns.catplot(data=prop,x='day',y='total_bill',kind='box')

# %%
sns.catplot(data=prop,x='day',y='total_bill',kind='box',hue='smoker')

# %%
prop['finde']=prop['day'].isin(['Sat','Sun'])

# %%
prop
# Out:
#      total_bill   tip     sex smoker   day    time  size  finde
# 0         16.99  1.01  Female     No   Sun  Dinner     2   True
# 1         10.34  1.66    Male     No   Sun  Dinner     3   True
# 2         21.01  3.50    Male     No   Sun  Dinner     3   True
# 3         23.68  3.31    Male     No   Sun  Dinner     2   True
# 4         24.59  3.61  Female     No   Sun  Dinner     4   True
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   True
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   True
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   True
# 242       17.82  1.75    Male     No   Sat  Dinner     2   True
# 243       18.78  3.00  Female     No  Thur  Dinner     2  False
#
# [244 rows x 8 columns]

# %%
sns.catplot(data=prop,x='day',y='total_bill',kind='box',dodge=False,hue='finde')

# %%
diamante=sns.load_dataset("diamonds")

# %%
diamante
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(data=diamante.sort_values('color'),x='color',y='price',kind='boxen')

# %%
sns.catplot(data=prop,x='total_bill',y='day',hue='sex',kind='violin')

# %%
sns.catplot(data=prop,x='total_bill',y='day',hue='sex',kind='violin',bw=0.15,cut=0)

# %%
sns.catplot(data=prop,y='total_bill',x='day',hue='sex',kind='violin')

# %%
sns.catplot(data=prop,y='total_bill',x='day',hue='sex',kind='violin',split=True)

# %%
sns.catplot(data=prop,y='total_bill',x='day',hue='sex',kind='violin',split=True,inner='stick',palette='viridis')

# %%
g=sns.catplot(data=prop,y='total_bill',x='day',kind='violin',split=True,inner=None,palette='viridis')

# %%
g=sns.catplot(data=prop,y='total_bill',x='day',kind='violin',split=True,inner=None,palette='viridis')
sns.swarmplot(data=prop,y='total_bill',x='day',color='k',size=3,ax=g.ax)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(data=titanic,x='sex',y='survived',hue='class',kind='bar')

# %%
sns.catplot(data=titanic,x='age',y='deck',kind='bar',errorbar=('pi',95))

# %%
sns.catplot(data=titanic,y='deck',kind='count',palette='Blues',hue='class')

# %%
sns.catplot(data=prop,x='day',y='total_bill',hue='smoker',kind='swarm',col='time',aspect=0.6)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.catplot(
    data=titanic,
    x="fare", y="embark_town", row="class",
    kind="box", orient="h",
    sharex=False, margin_titles=True,
    height=1.5, aspect=4,
)
g.set(xlabel="Fare", ylabel="")
g.set_titles(row_template="{row_name} class")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter('${x:.0f}')
