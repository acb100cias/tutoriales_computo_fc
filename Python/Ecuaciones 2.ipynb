# %% [markdown]
# # Ecuaciones diferenciales. Sistemas
#
# ## Problema 1. El oscilador armónico
#
# $$
# \dfrac{\mathrm{d}^2y}{\mathrm{d}t^2}=a\dfrac{\mathrm{d}y}{\mathrm{d}t}+by+c
# $$
#
# ## Problema 2. Sistema Lotka -Volterra
#
# $$
# \begin{eqnarray}
# \dfrac{\mathrm{d}x}{\mathrm{d}t}=\alpha x -\beta xy \\
# \dfrac{\mathrm{d}y}{\mathrm{d}t}=-\gamma y + \delta xy
# \end{eqnarray}
# $$
#
# ## Problema 3. Sistema de Lorenz
#
#
# $$
# \dot{x}=\sigma(y-x)\\
# \dot{y}=x(\rho-z)-y\\
# \dot{z}=xy-\beta z
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
def f(Y,t):
    y1,y2=Y
    return [y2,-k*y1-b*y2+4*np.cos(2*t)]

# %%
k=10.
b=2.

# %%
y0=[0.5,0]

# %%
T=np.arange(0,20,0.1)
ys=odeint(f,y0,T)

# %%
ys
# Out:
# array([[ 0.5       ,  0.        ],
#        [ 0.49529189, -0.09165349],
#        [ 0.48201368, -0.17292799],
#        [ 0.46077511, -0.25205556],
#        [ 0.43147701, -0.33484773],
#        [ 0.39358628, -0.42411203],
#        [ 0.34644691, -0.51950914],
#        [ 0.28958534, -0.6178007 ],
#        [ 0.22297447, -0.71340886],
#        [ 0.14723035, -0.79919093],
#        [ 0.06372476, -0.86732657],
#        [-0.02539234, -0.910219  ],
#        [-0.11725748, -0.92132345],
#        [-0.20843473, -0.89583442],
#        [-0.29511615, -0.83118383],
#        [-0.37336163, -0.72732442],
#        [-0.43935591, -0.5867936 ],
#        [-0.48966158, -0.41457124],
#        [-0.52144865, -0.21775936],
#        [-0.53268471, -0.00512211],
#        [-0.52227403,  0.21346974],
#        [-0.49013815,  0.42764374],
#        [-0.43723543,  0.62713627],
#        [-0.3655209 ,  0.80236895],
#        [-0.27785156,  0.94495847],
#        [-0.17784512,  1.04813508],
#        [-0.06970218,  1.10705345],
# ...

# %%
plt.plot(T,ys[:,0],label='posición')
plt.plot(T,ys[:,1],label='Velocidad')
plt.legend()

# %%
plt.plot(ys[:,0],ys[:,1])

# %%
T=np.arange(0,50,0.1)
for ci in [0,0.5,1,1.5,2,2.5]:
    y0=[ci,0]
    ys=odeint(f,y0,T)
    plt.plot(ys[:,0],ys[:,1],label='%f'%ci)
plt.legend()
plt.title('Trayectorias en el plano fase')
plt.xlabel('Posición')
plt.ylabel('velocidad')
# Out:
# Text(0, 0.5, 'velocidad')

# %%
def g(Y,t):
    y1,y2=Y
    return [a*y1-b*y1*y2,-c*y1+d*y1*y2]

# %%
a=0.4
b=0.2
c=0.5
d=0.4

# %%
y0=[2,1]
ys=odeint(g,y0,T)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
ys
# Out:
# array([[ 2.00000000e+000,  1.00000000e+000],
#        [ 2.04082483e+000,  9.78958525e-001],
#        [ 2.08340569e+000,  9.55655655e-001],
#        [ 2.12791981e+000,  9.29792222e-001],
#        [ 2.17457143e+000,  9.01020745e-001],
#        [ 2.22359696e+000,  8.68935950e-001],
#        [ 2.27527153e+000,  8.33062834e-001],
#        [ 2.32991687e+000,  7.92842109e-001],
#        [ 2.38791140e+000,  7.47611581e-001],
#        [ 2.44970289e+000,  6.96582686e-001],
#        [ 2.51582479e+000,  6.38810239e-001],
#        [ 2.58691708e+000,  5.73153455e-001],
#        [ 2.66375374e+000,  4.98224744e-001],
#        [ 2.74727893e+000,  4.12321799e-001],
#        [ 2.83865555e+000,  3.13336277e-001],
#        [ 2.93933144e+000,  1.98628989e-001],
#        [ 3.05113082e+000,  6.48567038e-002],
#        [ 3.17638362e+000, -9.22732195e-002],
#        [ 3.31811168e+000, -2.78357556e-001],
#        [ 3.48030383e+000, -5.00822756e-001],
#        [ 3.66833362e+000, -7.69725504e-001],
# ...

# %%
plt.plot(T,ys[:,0],label='presa')
plt.plot(T,ys[:,1],label='depredador')
plt.legend()

# %%
plt.plot(ys[:,0],ys[:,1])

# %%
def lorenz(x, y, z, s=10, r=28, b=2.667):
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return [x_dot, y_dot, z_dot]

# %%
sol_lorenz=odeint(lorenz(0,1.,1.05),[0,1,1.05],np.arange(0,100,0.1))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-67-6c60f272d957> in <module>
# ----> 1 sol_lorenz=odeint(lorenz(0,1.,1.05),[0,1,1.05],np.arange(0,100,0.1))
#
# /usr/local/lib/python3.7/site-packages/scipy/integrate/odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     242                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 244                              int(bool(tfirst)))
#     245     if output[-1] < 0:
#     246         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# error: The function and its Jacobian must be callable functions.

# %%
dt = 0.01
num_steps = 10000

xs = np.empty(num_steps + 1)
ys = np.empty(num_steps + 1)
zs = np.empty(num_steps + 1)


xs[0], ys[0], zs[0] = (0., 1., 1.05)

# %%
for i in range(num_steps):
    x_dot, y_dot, z_dot = lorenz(xs[i], ys[i], zs[i])
    xs[i + 1] = xs[i] + (x_dot * dt)
    ys[i + 1] = ys[i] + (y_dot * dt)
    zs[i + 1] = zs[i] + (z_dot * dt)

# %%
plt.plot(xs)
plt.plot(ys)

plt.plot(zs)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(xs, ys, zs, lw=0.5)
ax.set_title("Atractor de Lorenz")
# Out:
# Text(0.5, 0.92, 'Atractor de Lorenz')
